# %%
import pandas as pd

df = pd.read_csv(csv_file_path)

df.head()
# Out:
#                                           Audio Urls  Sr. No. Caller Name  \
# 0  https://konnect.knowlarity.com/konnect/api/v1/...        1     Deeksha
# 1  https://konnect.knowlarity.com/konnect/api/v1/...        2       sadaf
# 2  https://konnect.knowlarity.com/konnect/api/v1/...        3    abhishek
# 3  https://konnect.knowlarity.com/konnect/api/v1/...        4    abhishek
# 4  https://konnect.knowlarity.com/konnect/api/v1/...        5        Aman
#
#          Date  Ticket ID Client ID Expected Type of Query  \
# 0  15/06/2024    3625616   P200052         login-guidance
# 1  15/06/2024    3625219    R01592         login-guidance
# 2  15/06/2024    3633028   X176289            order-magin
# 3  15/06/2024    3633779    PXW087    corporate action-RE
# 4  15/06/2024    3635093   X172496              brokerage
#
#   Predicted Type of Query  Expected Greetings  Predicted Greetings  ...  \
# 0          Login Guidance                   1                    1  ...
# ...

# %%
columns = df.columns

# %%
columns
# Out:
# Index(['Audio Urls', 'Sr. No.', 'Caller Name', 'Date', 'Ticket ID',
#        'Client ID', 'Expected Type of Query', 'Predicted Type of Query',
#        'Expected Greetings', 'Predicted Greetings', 'Expected Empathy Score',
#        'Predicted Empathy Score', 'Expected Closure', 'Predicted Closure',
#        'Expected Total', 'Total', 'Original Remark', 'Transcript', 'Summary',
#        'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
df['V2 Predictions'] = None

df.head(5)
# Out:
#                                           Audio Urls  Sr. No. Caller Name  \
# 0  https://konnect.knowlarity.com/konnect/api/v1/...        1     Deeksha
# 1  https://konnect.knowlarity.com/konnect/api/v1/...        2       sadaf
# 2  https://konnect.knowlarity.com/konnect/api/v1/...        3    abhishek
# 3  https://konnect.knowlarity.com/konnect/api/v1/...        4    abhishek
# 4  https://konnect.knowlarity.com/konnect/api/v1/...        5        Aman
#
#          Date  Ticket ID Client ID Expected Type of Query  \
# 0  15/06/2024    3625616   P200052         login-guidance
# 1  15/06/2024    3625219    R01592         login-guidance
# 2  15/06/2024    3633028   X176289            order-magin
# 3  15/06/2024    3633779    PXW087    corporate action-RE
# 4  15/06/2024    3635093   X172496              brokerage
#
#   Predicted Type of Query  Expected Greetings  Predicted Greetings  ...  \
# 0          Login Guidance                   1                    1  ...
# ...

# %%
from query_type import *

for index, row in df.iterrows():
    # 1. Take the transcript
    transcript = row['Transcript']

    # 2. Generate a summary
    summary = generate_summary(transcript=transcript)
    print("Summary generated for ", index)

    # 3. Get query type
    query_type = get_main_query(summary=summary)
    print("Query type generatef for ", index)

    # Update in dataframe
    df.at[index, 'V2 Predictions'] = query_type
    print(index)
# Out:
# Summary generated for  0
# Query type generatef for  0
# 0
# Summary generated for  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#       9 print("Summary generated for ", index)
#      11 # 3. Get query type
# ---> 12 query_type = get_main_query(summary=summary)
#      13 print("Query type generatef for ", index)
#      15 # Update in dataframe
#
# File ~/Desktop/sentiment-analysis/query-types/query_type.py:62, in get_main_query(summary)
#      58 system_prompt = f"You are a professional transcript analyzer for a finance platform, for a given transcript summary between the platform agent and the customer categorize the problem in the query type from the given list: {main_query_description}. Just return the name of the query and nothing else."
# ...
